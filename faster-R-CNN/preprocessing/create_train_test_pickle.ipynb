# %%
import pandas as pd
import numpy as np
import pickle
import re
import random
import sys

# %% [markdown]
# ### Processing sim images

# %%
sim = pd.DataFrame(columns=['filename', 'xmins', 'xmaxs', 'ymins', 'ymaxs', 
                            'classes', 'classes_text', 'height', 'width'])

i = 0
h = 600
w = 800
labels = [b'red', b'yellow', b'green']

for idx, csvFile in enumerate(['data/red_sim.csv', 'data/yellow_sim.csv', 'data/green_sim.csv']):
    df = pd.read_csv(csvFile)

    for j in range(df.shape[0]):
        xmin, ymin, u, v = re.findall(r'\d+', df.iloc[j, 5])
        sim.loc[i] = [df.iloc[j, 0],
                     float(xmin)/w, 
                     (float(xmin)+float(u))/w, 
                     float(ymin)/h, 
                     (float(ymin)+float(v))/h, 
                     int(idx+1),
                     labels[idx],
                     int(h),
                     int(w)]        
        i = i + 1

sim.head()
# Out:
#              filename    xmins    xmaxs     ymins     ymaxs classes  \
# 0  sim_1507476460.png  0.15875  0.23125  0.476667  0.688333       1
# 1  sim_1507476460.png  0.46750  0.53750  0.483333  0.701667       1
# 2  sim_1507476460.png  0.77750  0.84875  0.491667  0.703333       1
# 3  sim_1507476461.png  0.16250  0.23000  0.476667  0.688333       1
# 4  sim_1507476461.png  0.46500  0.53875  0.478333  0.698333       1
#
#   classes_text height width
# 0       b'red'    600   800
# 1       b'red'    600   800
# 2       b'red'    600   800
# 3       b'red'    600   800
# 4       b'red'    600   800

# %%
assert sim.apply(lambda row: (row['xmins'] <= row['xmaxs']) & 
                 (row['ymins'] <= row['ymaxs']), axis = 1).sum() == sim.shape[0]

# %%
sim[['filename', 'classes_text']].groupby('classes_text').count()
# Out:
#               filename
# classes_text
# b'green'            61
# b'red'             323
# b'yellow'           54

# %%
sim_groups = pd.DataFrame({'filename': sim.filename.unique()})

for col in sim.columns[1:]:
    sim_group = sim.groupby('filename')[col].apply(np.hstack).to_frame().reset_index()
    if col not in ['height', 'width']:
        sim_groups = pd.merge(sim_groups, sim_group, on='filename')
    else:
        sim_group[col] = sim_group[col].apply(lambda r: r if len(set(r)) > 1 else r[0])
        sim_groups = pd.merge(sim_groups, sim_group, on='filename')
        
sim_groups['class_text'] = sim_groups['classes_text'].apply(lambda r: r if len(set(r)) > 1 else r[0])

sim_groups.head()
# Out:
#              filename                       xmins                       xmaxs  \
# 0  sim_1507476460.png   [0.15875, 0.4675, 0.7775]  [0.23125, 0.5375, 0.84875]
# 1  sim_1507476461.png     [0.1625, 0.465, 0.7775]       [0.23, 0.53875, 0.85]
# 2  sim_1507476462.png      [0.155, 0.46375, 0.78]    [0.22875, 0.54, 0.85125]
# 3  sim_1507476463.png  [0.15625, 0.46625, 0.7775]    [0.22625, 0.54, 0.85375]
# 4  sim_1507476464.png       [0.155, 0.4675, 0.78]       [0.225, 0.54, 0.8575]
#
#                                               ymins  \
# 0  [0.476666666667, 0.483333333333, 0.491666666667]
# 1  [0.476666666667, 0.478333333333, 0.491666666667]
# 2  [0.476666666667, 0.481666666667, 0.493333333333]
# 3  [0.473333333333, 0.483333333333, 0.493333333333]
# 4  [0.466666666667, 0.473333333333, 0.481666666667]
#
#                                               ymaxs    classes  \
# 0  [0.688333333333, 0.701666666667, 0.703333333333]  [1, 1, 1]
# 1  [0.688333333333, 0.698333333333, 0.703333333333]  [1, 1, 1]
# 2           [0.688333333333, 0.701666666667, 0.705]  [1, 1, 1]
# 3           [0.685, 0.696666666667, 0.701666666667]  [1, 1, 1]
# 4  [0.683333333333, 0.693333333333, 0.698333333333]  [1, 1, 1]
#
#                classes_text  height  width class_text
# 0  [b'red', b'red', b'red']     600    800     b'red'
# 1  [b'red', b'red', b'red']     600    800     b'red'
# 2  [b'red', b'red', b'red']     600    800     b'red'
# 3  [b'red', b'red', b'red']     600    800     b'red'
# 4  [b'red', b'red', b'red']     600    800     b'red'

# %%
sim_groups[['filename', 'class_text']].groupby('class_text').count()
# Out:
#             filename
# class_text
# b'green'          21
# b'red'           112
# b'yellow'         18

# %%
assert sim_groups.dropna().shape == sim_groups.shape

# %% [markdown]
# ### Processing site images

# %%
site = pd.DataFrame(columns=['filename', 'xmins', 'xmaxs', 'ymins', 'ymaxs', 
                            'classes', 'classes_text', 'height', 'width'])

i = 0
h = 1096
w = 1368
labels = [b'red', b'yellow', b'green']

for idx, pickleFile in enumerate(['data/red.p', 'data/yellow.p', 'data/green.p']):
    
    with open(pickleFile, 'rb') as f:
        df = pickle.load(f)
    
    if df.apply(lambda row: row['id'].find('site') > -1, axis = 1).sum() > 0: 
        
        for j in range(df.shape[0]):
            
            if df.iloc[j, 0].find('site') > -1: 
            
                best_box_prob = max(df.iloc[j, 2][0][df.iloc[j, 3][0] == 10])
                if best_box_prob > 0.9: 
                    box = df.iloc[j, 1][0][df.iloc[j, 2][0] == best_box_prob][0]
                    ymin, xmin, ymax, xmax = box[0], box[1], box[2], box[3]
                    site.loc[i] = [df.iloc[j, 0].split('/')[1],
                                  xmin, 
                                  xmax, 
                                  ymin, 
                                  ymax, 
                                  int(idx+1),
                                  labels[idx],
                                  int(h),
                                  int(w)]        
                    i = i + 1
                
site.head()
# Out:
#                         filename     xmins     xmaxs     ymins     ymaxs  \
# 0   site_1507478284.39343118.png  0.528541  0.552816  0.358023  0.448821
# 1  site_1507478206.566551923.png  0.549060  0.570155  0.358148  0.441864
# 2  site_1507478130.261214017.png  0.533648  0.559435  0.355488  0.451758
# 3  site_1507478208.300426959.png  0.496642  0.529880  0.330892  0.445462
# 4  site_1507478285.520903110.png  0.468447  0.506748  0.335749  0.466605
#
#   classes classes_text height width
# 0       1       b'red'   1096  1368
# 1       1       b'red'   1096  1368
# 2       1       b'red'   1096  1368
# 3       1       b'red'   1096  1368
# 4       1       b'red'   1096  1368

# %%
assert site.apply(lambda row: (row['xmins'] <= row['xmaxs']) & 
                  (row['ymins'] <= row['ymaxs']), axis = 1).sum() == site.shape[0]

# %%
site[['filename', 'classes_text']].groupby('classes_text').count()
# Out:
#               filename
# classes_text
# b'green'            94
# b'red'              67

# %%
site_groups = pd.DataFrame({'filename': site.filename.unique()})

for col in site.columns[1:]:
    site_group = site.groupby('filename')[col].apply(np.hstack).to_frame().reset_index()
    if col not in ['height', 'width']:
        site_groups = pd.merge(site_groups, site_group, on='filename')
    else:
        site_group[col] = site_group[col].apply(lambda r: r if len(set(r)) > 1 else r[0])
        site_groups = pd.merge(site_groups, site_group, on='filename')
        
site_groups['class_text'] = site_groups['classes_text'].apply(lambda r: r if len(set(r)) > 1 else r[0])

site_groups.head()
# Out:
#                         filename             xmins             xmaxs  \
# 0   site_1507478284.39343118.png  [0.528540670872]  [0.552815794945]
# 1  site_1507478206.566551923.png   [0.54905962944]  [0.570155441761]
# 2  site_1507478130.261214017.png  [0.533647656441]  [0.559434711933]
# 3  site_1507478208.300426959.png  [0.496641904116]  [0.529880404472]
# 4  site_1507478285.520903110.png  [0.468447417021]  [0.506748378277]
#
#               ymins             ymaxs classes classes_text  height  width  \
# 0  [0.358022719622]  [0.448820501566]     [1]     [b'red']    1096   1368
# 1  [0.358147650957]  [0.441863626242]     [1]     [b'red']    1096   1368
# 2  [0.355487972498]   [0.45175793767]     [1]     [b'red']    1096   1368
# 3  [0.330892294645]  [0.445461839437]     [1]     [b'red']    1096   1368
# 4  [0.335749238729]  [0.466605275869]     [1]     [b'red']    1096   1368
#
#   class_text
# 0     b'red'
# 1     b'red'
# 2     b'red'
# 3     b'red'
# 4     b'red'

# %%
site_groups[['filename', 'class_text']].groupby('class_text').count()
# Out:
#             filename
# class_text
# b'green'          94
# b'red'            67

# %%
assert site_groups.dropna().shape == site_groups.shape

# %% [markdown]
# ### Combine sim and site, split into train and test

# %%
sim_red = sim_groups[sim_groups.class_text == b'red'].reset_index(drop=True).loc[random.sample(range(112), 20)]
sim_green = sim_groups[sim_groups.class_text == b'green'].reset_index(drop=True).loc[random.sample(range(21), 21)]
sim_yellow = sim_groups[sim_groups.class_text == b'yellow'].reset_index(drop=True).loc[random.sample(range(18), 18)]

site_red = site_groups[site_groups.class_text == b'red'].reset_index(drop=True).loc[random.sample(range(67), 67)]
site_green = site_groups[site_groups.class_text == b'green'].reset_index(drop=True).loc[random.sample(range(94), 67)]

# %%
combined = pd.concat([sim_red, sim_green, sim_yellow, site_red, site_green]).reset_index(drop=True)

random.seed(42)

mySplit = random.sample(range(combined.shape[0]), combined.shape[0])

train = combined.loc[mySplit[:int(len(mySplit)*0.7)]]
test = combined.loc[mySplit[int(len(mySplit)*0.7):]]

# %%
print(train.shape)
train.head()
train[['filename', 'class_text']].groupby('class_text').count()
# Out:
# (135, 10)
#             filename
# class_text
# b'green'          64
# b'red'            57
# b'yellow'         14

# %%
print(test.shape)
test.head()
test[['filename', 'class_text']].groupby('class_text').count()
# Out:
# (58, 10)
#             filename
# class_text
# b'green'          24
# b'red'            30
# b'yellow'          4

# %%
with open('data/train.p', 'wb') as f:
    pickle.dump(train, f)
with open('data/test.p', 'wb') as f:
    pickle.dump(test, f)

# %%
with open('data/train.p', 'rb') as f:
    train = pickle.load(f)

train.head()
# Out:
#                           filename                        xmins  \
# 163  site_1507478178.229204893.png             [0.467687249184]
# 28              sim_1507476784.png  [0.59875, 0.66375, 0.72875]
# 6               sim_1507476584.png           [0.40875, 0.89875]
# 189  site_1507478175.145765066.png             [0.912817656994]
# 70   site_1507478284.322890996.png             [0.512386381626]
#
#                       xmaxs                                             ymins  \
# 163        [0.495300710201]                                  [0.344213575125]
# 28   [0.6175, 0.6775, 0.74]  [0.958333333333, 0.956666666667, 0.963333333333]
# 6           [0.53, 0.99625]                                    [0.105, 0.145]
# 189        [0.933615684509]                                  [0.366456270218]
# 70         [0.544706523418]                                  [0.338917464018]
#
#                                                 ymaxs    classes  \
# 163                                  [0.453657537699]        [3]
# 28   [0.998333333333, 0.998333333333, 0.998333333333]  [3, 3, 3]
# 6                                       [0.445, 0.48]     [1, 1]
# 189                                  [0.433692902327]        [3]
# 70                                   [0.448389649391]        [1]
#
#                        classes_text  height  width class_text
# 163                      [b'green']    1096   1368   b'green'
# 28   [b'green', b'green', b'green']     600    800   b'green'
# 6                  [b'red', b'red']     600    800     b'red'
# 189                      [b'green']    1096   1368   b'green'
# 70                         [b'red']    1096   1368     b'red'

# %%
with open('data/test.p', 'rb') as f:
    test = pickle.load(f)
    
test.head()
# Out:
#                           filename             xmins             xmaxs  \
# 192  site_1507478254.330929040.png  [0.534319579601]  [0.556203961372]
# 186  site_1507478252.846045970.png  [0.678090155125]  [0.697143912315]
# 159  site_1507478099.480123996.png  [0.711354732513]  [0.731728136539]
# 130  site_1507478176.931401014.png  [0.595603168011]   [0.61523014307]
# 76   site_1507478283.400125026.png  [0.541101157665]  [0.564745664597]
#
#                 ymins             ymaxs classes classes_text  height  width  \
# 192  [0.357933878899]   [0.44446772337]     [3]   [b'green']    1096   1368
# 186  [0.360238850117]  [0.433399558067]     [3]   [b'green']    1096   1368
# 159  [0.364539712667]  [0.444752961397]     [3]   [b'green']    1096   1368
# 130  [0.359343379736]  [0.434265553951]     [3]   [b'green']    1096   1368
# 76   [0.355073392391]  [0.445116072893]     [1]     [b'red']    1096   1368
#
#     class_text
# 192   b'green'
# 186   b'green'
# 159   b'green'
# 130   b'green'
# 76      b'red'

# %%
print(train.shape)
print(test.shape)
# Out:
# (135, 10)
# (58, 10)

# %% [markdown]
# ### Add Some Extra Images

# %%
import pandas as pd
import numpy as np
import pickle
import re
import random
import sys

# %%
extra = pd.DataFrame(columns=['filename', 'xmins', 'xmaxs', 'ymins', 'ymaxs', 
                              'classes', 'classes_text', 'height', 'width'])

i = 0
h = 600
w = 800
labels = [b'red', b'yellow', b'green']

for idx, csvFile in enumerate(['data/extra_png.csv']):
    df = pd.read_csv(csvFile)

    for j in range(df.shape[0]):
        xmin, ymin, u, v = re.findall(r'\d+', df.iloc[j, 5])
        class_label = re.sub("[^A-Za-z]", " ", df.iloc[j, 6].strip("")).split()[1].encode()
        extra.loc[i] = [df.iloc[j, 0],
                         float(xmin)/w, 
                         (float(xmin)+float(u))/w, 
                         float(ymin)/h, 
                         (float(ymin)+float(v))/h, 
                         int(labels.index(class_label)+1),
                         class_label,
                         int(h),
                         int(w)]        
        i = i + 1

extra.head()
# Out:
#      filename    xmins    xmaxs     ymins     ymaxs classes classes_text  \
# 0  green1.png  0.23500  0.27375  0.395000  0.493333       3     b'green'
# 1  green1.png  0.48625  0.52250  0.433333  0.531667       3     b'green'
# 2  green1.png  0.92125  0.95500  0.648333  0.728333       3     b'green'
# 3  green2.png  0.50500  0.58125  0.376667  0.680000       3     b'green'
# 4  green3.png  0.50500  0.69750  0.128333  0.885000       3     b'green'
#
#   height width
# 0    600   800
# 1    600   800
# 2    600   800
# 3    600   800
# 4    600   800

# %%
extra_groups = pd.DataFrame({'filename': extra.filename.unique()})

for col in extra.columns[1:]:
    extra_group = extra.groupby('filename')[col].apply(np.hstack).to_frame().reset_index()
    if col not in ['height', 'width']:
        extra_groups = pd.merge(extra_groups, extra_group, on='filename')
    else:
        extra_group[col] = extra_group[col].apply(lambda r: r if len(set(r)) > 1 else r[0])
        extra_groups = pd.merge(extra_groups, extra_group, on='filename')
        
extra_groups['class_text'] = extra_groups['classes_text'].apply(lambda r: r if len(set(r)) > 1 else r[0])

extra_groups.head()
# Out:
#      filename                      xmins                     xmaxs  \
# 0  green1.png  [0.235, 0.48625, 0.92125]  [0.27375, 0.5225, 0.955]
# 1  green2.png                    [0.505]                 [0.58125]
# 2  green3.png                    [0.505]                  [0.6975]
# 3    red1.png                    [0.405]                   [0.525]
# 4    red2.png                     [0.58]                  [0.7925]
#
#                                      ymins  \
# 0  [0.395, 0.433333333333, 0.648333333333]
# 1                         [0.376666666667]
# 2                         [0.128333333333]
# 3                                    [0.2]
# 4                         [0.113333333333]
#
#                                               ymaxs    classes  \
# 0  [0.493333333333, 0.531666666667, 0.728333333333]  [3, 3, 3]
# 1                                            [0.68]        [3]
# 2                                           [0.885]        [3]
# 3                                            [0.62]        [1]
# 4                                  [0.971666666667]        [1]
#
#                      classes_text  height  width class_text
# 0  [b'green', b'green', b'green']     600    800   b'green'
# 1                      [b'green']     600    800   b'green'
# 2                      [b'green']     600    800   b'green'
# 3                        [b'red']     600    800     b'red'
# 4                        [b'red']     600    800     b'red'

# %%
with open('data/train.p', 'rb') as f:
    train = pickle.load(f)

train.head()
# Out:
#                           filename                        xmins  \
# 163  site_1507478178.229204893.png             [0.467687249184]
# 28              sim_1507476784.png  [0.59875, 0.66375, 0.72875]
# 6               sim_1507476584.png           [0.40875, 0.89875]
# 189  site_1507478175.145765066.png             [0.912817656994]
# 70   site_1507478284.322890996.png             [0.512386381626]
#
#                       xmaxs                                             ymins  \
# 163        [0.495300710201]                                  [0.344213575125]
# 28   [0.6175, 0.6775, 0.74]  [0.958333333333, 0.956666666667, 0.963333333333]
# 6           [0.53, 0.99625]                                    [0.105, 0.145]
# 189        [0.933615684509]                                  [0.366456270218]
# 70         [0.544706523418]                                  [0.338917464018]
#
#                                                 ymaxs    classes  \
# 163                                  [0.453657537699]        [3]
# 28   [0.998333333333, 0.998333333333, 0.998333333333]  [3, 3, 3]
# 6                                       [0.445, 0.48]     [1, 1]
# 189                                  [0.433692902327]        [3]
# 70                                   [0.448389649391]        [1]
#
#                        classes_text  height  width class_text
# 163                      [b'green']    1096   1368   b'green'
# 28   [b'green', b'green', b'green']     600    800   b'green'
# 6                  [b'red', b'red']     600    800     b'red'
# 189                      [b'green']    1096   1368   b'green'
# 70                         [b'red']    1096   1368     b'red'

# %%
train_extra = pd.concat([train, extra_groups]).reset_index(drop=True)

random.seed(42)

mySplit = random.sample(range(train_extra.shape[0]), train_extra.shape[0])

train_extra = train_extra.loc[mySplit].reset_index(drop=True)

train_extra.loc[10:20]
# Out:
#                          filename                     xmins  \
# 10             sim_1507476953.png   [0.00625, 0.1, 0.18875]
# 11             raw_1507390380.png   [0.1575, 0.465, 0.7775]
# 12             sim_1507476792.png  [0.5075, 0.6125, 0.7225]
# 13  site_1507478232.613333940.png          [0.220287665725]
# 14  site_1507478209.915699005.png          [0.350768566132]
# 15                    yellow3.png                 [0.51625]
# 16  site_1507478129.435110092.png          [0.559038758278]
# 17  site_1507478252.594393014.png          [0.711354732513]
# 18  site_1507478179.452856063.png          [0.103271611035]
# 19                       red4.png         [0.2425, 0.93875]
# 20  site_1507478284.632946968.png          [0.503149688244]
#
#                           xmaxs  \
# 10  [0.03125, 0.12375, 0.21375]
# 11     [0.22625, 0.53875, 0.85]
# 12   [0.53375, 0.6375, 0.74875]
# 13             [0.266950458288]
# 14             [0.399386614561]
# 15                      [0.755]
# 16             [0.581975519657]
# 17             [0.731728136539]
# 18             [0.162069112062]
# 19              [0.28375, 0.98]
# 20             [0.532261073589]
#
#                                                ymins  \
# 10            [0.891666666667, 0.886666666667, 0.89]
# 11  [0.476666666667, 0.488333333333, 0.496666666667]
# 12           [0.863333333333, 0.865, 0.866666666667]
# 13                                    [0.3217253685]
# 14                                  [0.328565776348]
# 15                                  [0.111666666667]
# 16                                  [0.354843735695]
# 17                                  [0.364539712667]
# 18                                  [0.311506956816]
# 19                 [0.131666666667, 0.0266666666667]
# 20                                  [0.338035702705]
#
#                                       ymaxs    classes  \
# 10            [0.95, 0.953333333333, 0.955]  [3, 3, 3]
# 11  [0.688333333333, 0.698333333333, 0.705]  [2, 2, 2]
# 12            [0.94, 0.941666666667, 0.945]  [1, 1, 1]
# 13                         [0.472235262394]        [3]
# 14                         [0.475778728724]        [1]
# 15                                  [0.965]        [2]
# 16                         [0.441536158323]        [1]
# 17                         [0.444752961397]        [3]
# 18                           [0.4911467731]        [3]
# 19                  [0.255, 0.171666666667]     [1, 1]
# 20                         [0.445245414972]        [1]
#
#                          classes_text  height  width class_text
# 10     [b'green', b'green', b'green']     600    800   b'green'
# 11  [b'yellow', b'yellow', b'yellow']     600    800  b'yellow'
# 12           [b'red', b'red', b'red']     600    800     b'red'
# 13                         [b'green']    1096   1368   b'green'
# 14                           [b'red']    1096   1368     b'red'
# 15                        [b'yellow']     600    800  b'yellow'
# 16                           [b'red']    1096   1368     b'red'
# 17                         [b'green']    1096   1368   b'green'
# 18                         [b'green']    1096   1368   b'green'
# 19                   [b'red', b'red']     600    800     b'red'
# 20                           [b'red']    1096   1368     b'red'

# %%
with open('data/train_extra.p', 'wb') as f:
    pickle.dump(train_extra, f)
